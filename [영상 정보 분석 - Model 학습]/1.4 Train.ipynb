# %% [markdown]
# ## 1.4 Train

# %%
history = model.fit_generator(
    train_gen,
    validation_data=val_gen,
    epochs=5,
    callbacks=[
        ModelCheckpoint(
		'model2.h5', monitor='val_acc', save_best_only=True, verbose=1)
		]
)

# %% [markdown]
# - 5번 반복 훈련을 진행한다.
# - 로컬에서 진행된 모델링이다보니 작동중 중단현상이 심하게 발생하여 epoch 을 5로 제한했다.
