# %% [markdown]
# ## 2.4 __main__

# %%
def running():

 ##### 주차구역별 좌표값 ##### 
value =
[[[23,170],[98,233]],[[98,162],[168,221]],[[182,121],[238,159]],[[242,115],[303,160]],[[303,122],[348,151]],[[361,115],[414,145]],[[425,114],[468,140]],[[474,107],[519,134]],[[502,77],[571,133]],[[567,86],[626,130]]
           ,[[649,112],[704,153]],[[701,143],[742,169]],[[728,141],[767,179]],[[759,161],[810,201]],[[811,176],[865,222]],[[224,218],[298,263]],[[268,261],[310,293]],[[278,294],[334,334]],[[279,343],[350,385]],[[276,397],[362,462]]
           ,[[304,474],[406,554]],[[495,236],[543,283]],[[512,281],[572,327]],[[554,313],[611,366]],[[731,328],[805,397]],[[648,423],[744,496]],[[702,491],[809,583]],[[866,581],[956,631]]]

      for i in range(1,5):
        image = run(i,value)
	.cv.imshow(imgae)
    return 0

running()

# %% [markdown]
# - running()을 호출함으로써 프로그램이 동작된다.
# - value에 좌표값을 넣어두고 run()을 호출 할 때 주차장 사진의 number 와 value     list를 보낸다.
